# %%
import pandas as pd

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
url = "imports-85.csv"
col_names=['symboling','normalized-losses','fuel-type','aspiration','num-of-doors','body-style','drive-wheels','engine-location','wheel-base',
                                    'length','width','height','curb-weight','engine-type','num-of-cylinders','engine-size',
                                    'fuel-system','bore','stroke','compression-ratio','horsepower','peak-rpm','city-mpg','highway-mpg','price']

df_car = pd.read_csv(url,sep=',',names = col_names ,na_values="?",  header=None)

# %%
df_car.shape
# Out:
# (205, 25)

# %%
df_car.head(5)
df_car.info()
df_car.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   fuel-type          205 non-null    object
#  3   aspiration         205 non-null    object
#  4   num-of-doors       203 non-null    object
#  5   body-style         205 non-null    object
#  6   drive-wheels       205 non-null    object
#  7   engine-location    205 non-null    object
#  8   wheel-base         205 non-null    float64
#  9   length             205 non-null    float64
#  10  width              205 non-null    float64
#  11  height             205 non-null    float64
#  12  curb-weight        205 non-null    int64
#  13  engine-type        205 non-null    object
#  14  num-of-cylinders   205 non-null    object
#  15  engine-size        205 non-null    int64
#  16  fuel-system        205 non-null    object
#  17  bore               201 non-null    float64
#  18  stroke             201 non-null    float64
#  19  compression-ratio  205 non-null    float64
#  20  horsepower         203 non-null    float64
#  21  peak-rpm           203 non-null    float64
#  22  city-mpg           205 non-null    int64
#  23  highway-mpg        205 non-null    int64
#  24  price              201 non-null    float64
# dtypes: float64(11), int64(5), object(9)
# memory usage: 40.2+ KB
# Index(['symboling', 'normalized-losses', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price'], dtype='object')

# %%
df_car = df_car[[ 'aspiration', 'num-of-doors',  'drive-wheels',  'num-of-cylinders']].copy()

# %%
df_car.head()
# Out:
#   aspiration num-of-doors drive-wheels num-of-cylinders
# 0        std          two          rwd             four
# 1        std          two          rwd             four
# 2        std          two          rwd              six
# 3        std         four          fwd             four
# 4        std         four          4wd             five

# %%
df_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   aspiration        205 non-null    object
#  1   num-of-doors      203 non-null    object
#  2   drive-wheels      205 non-null    object
#  3   num-of-cylinders  205 non-null    object
# dtypes: object(4)
# memory usage: 6.5+ KB

# %%
df_car['num-of-doors'].value_counts()
# Out:
# num-of-doors
# four    114
# two      89
# Name: count, dtype: int64

# %%
door_mapper = {"two": 2,
              "four": 4}

# %%
df_car['doors'] = df_car["num-of-doors"].replace(door_mapper)
# Out:
# /tmp/ipykernel_15317/1675203305.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_car['doors'] = df_car["num-of-doors"].replace(door_mapper)

# %%
df_car.head()
# Out:
#   aspiration num-of-doors drive-wheels num-of-cylinders  doors
# 0        std          two          rwd             four    2.0
# 1        std          two          rwd             four    2.0
# 2        std          two          rwd              six    2.0
# 3        std         four          fwd             four    4.0
# 4        std         four          4wd             five    4.0

# %%
df_car['num-of-cylinders'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        four
# 1        four
# 2         six
# 3        four
# 4        five
# 5        five
# 6        five
# 7        five
# 8        five
# 9        five
# 10       four
# 11       four
# 12        six
# 13        six
# 14        six
# 15        six
# 16        six
# 17        six
# 18      three
# 19       four
# 20       four
# 21       four
# 22       four
# 23       four
# 24       four
# 25       four
# 26       four
# 27       four
# 28       four
# 29       four
# 30       four
# 31       four
# 32       four
# 33       four
# 34       four
# 35       four
# 36       four
# 37       four
# 38       four
# 39       four
# 40       four
# 41       four
# 42       four
# 43       four
# 44       four
# 45       four
# 46       four
# 47        six
# 48        six
# 49     twelve
# 50       four
# 51       four
# 52       four
# 53       four
# 54       four
# 55        two
# 56        two
# 57        two
# 58        two
# 59       four
# 60       four
# 61       four
# 62       four
# 63       four
# 64       four
# 65       four
# 66       four
# 67       five
# 68       five
# 69       five
# 70       five
# 71      eight
# 72      eight
# 73      eight
# 74      eight
# 75       four
# 76       four
# 77       four
# 78       four
# 79       four
# 80       four
# 81       four
# 82       four
# 83       four
# 84       four
# 85       four
# 86       four
# 87       four
# 88       four
# 89       four
# 90       four
# 91       four
# 92       four
# 93       four
# 94       four
# 95       four
# 96       four
# 97       four
# 98       four
# 99       four
# 100      four
# 101       six
# 102       six
# 103       six
# 104       six
# 105       six
# 106       six
# 107      four
# 108      four
# 109      four
# 110      four
# 111      four
# 112      four
# 113      four
# 114      four
# 115      four
# 116      four
# 117      four
# 118      four
# 119      four
# 120      four
# 121      four
# 122      four
# 123      four
# 124      four
# 125      four
# 126       six
# 127       six
# 128       six
# 129     eight
# 130      four
# 131      four
# 132      four
# 133      four
# 134      four
# 135      four
# 136      four
# 137      four
# 138      four
# 139      four
# 140      four
# 141      four
# 142      four
# 143      four
# 144      four
# 145      four
# 146      four
# 147      four
# 148      four
# 149      four
# 150      four
# 151      four
# 152      four
# 153      four
# 154      four
# 155      four
# 156      four
# 157      four
# 158      four
# 159      four
# 160      four
# 161      four
# 162      four
# 163      four
# 164      four
# 165      four
# 166      four
# 167      four
# 168      four
# 169      four
# 170      four
# 171      four
# 172      four
# 173      four
# 174      four
# 175      four
# 176      four
# 177      four
# 178       six
# 179       six
# 180       six
# 181       six
# 182      four
# 183      four
# 184      four
# 185      four
# 186      four
# 187      four
# 188      four
# 189      four
# 190      four
# 191      five
# 192      four
# 193      four
# 194      four
# 195      four
# 196      four
# 197      four
# 198      four
# 199      four
# 200      four
# 201      four
# 202       six
# 203       six
# 204      four
# Name: num-of-cylinders, dtype: object>

# %%
cylinder_mapper = {"two":2,
                  "three":3,
                  "four":4,
                  "five":5,
                  "six":6,
                  "eight":8,
                  "twelve":12}

# %%
df_car['cylinders'] = df_car['num-of-cylinders'].replace(cylinder_mapper)
# Out:
# /tmp/ipykernel_15317/2926988077.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_car['cylinders'] = df_car['num-of-cylinders'].replace(cylinder_mapper)

# %%
df_car.head()
# Out:
#   aspiration num-of-doors drive-wheels num-of-cylinders  doors  cylinders
# 0        std          two          rwd             four    2.0          4
# 1        std          two          rwd             four    2.0          4
# 2        std          two          rwd              six    2.0          6
# 3        std         four          fwd             four    4.0          4
# 4        std         four          4wd             five    4.0          5

# %%
df_car['drive-wheels'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      rwd
# 1      rwd
# 2      rwd
# 3      fwd
# 4      4wd
# 5      fwd
# 6      fwd
# 7      fwd
# 8      fwd
# 9      4wd
# 10     rwd
# 11     rwd
# 12     rwd
# 13     rwd
# 14     rwd
# 15     rwd
# 16     rwd
# 17     rwd
# 18     fwd
# 19     fwd
# 20     fwd
# 21     fwd
# 22     fwd
# 23     fwd
# 24     fwd
# 25     fwd
# 26     fwd
# 27     fwd
# 28     fwd
# 29     fwd
# 30     fwd
# 31     fwd
# 32     fwd
# 33     fwd
# 34     fwd
# 35     fwd
# 36     fwd
# 37     fwd
# 38     fwd
# 39     fwd
# 40     fwd
# 41     fwd
# 42     fwd
# 43     rwd
# 44     fwd
# 45     fwd
# 46     rwd
# 47     rwd
# 48     rwd
# 49     rwd
# 50     fwd
# 51     fwd
# 52     fwd
# 53     fwd
# 54     fwd
# 55     rwd
# 56     rwd
# 57     rwd
# 58     rwd
# 59     fwd
# 60     fwd
# 61     fwd
# 62     fwd
# 63     fwd
# 64     fwd
# 65     rwd
# 66     rwd
# 67     rwd
# 68     rwd
# 69     rwd
# 70     rwd
# 71     rwd
# 72     rwd
# 73     rwd
# 74     rwd
# 75     rwd
# 76     fwd
# 77     fwd
# 78     fwd
# 79     fwd
# 80     fwd
# 81     fwd
# 82     fwd
# 83     fwd
# 84     fwd
# 85     fwd
# 86     fwd
# 87     fwd
# 88     fwd
# 89     fwd
# 90     fwd
# 91     fwd
# 92     fwd
# 93     fwd
# 94     fwd
# 95     fwd
# 96     fwd
# 97     fwd
# 98     fwd
# 99     fwd
# 100    fwd
# 101    fwd
# 102    fwd
# 103    fwd
# 104    rwd
# 105    rwd
# 106    rwd
# 107    rwd
# 108    rwd
# 109    rwd
# 110    rwd
# 111    rwd
# 112    rwd
# 113    rwd
# 114    rwd
# 115    rwd
# 116    rwd
# 117    rwd
# 118    fwd
# 119    fwd
# 120    fwd
# 121    fwd
# 122    fwd
# 123    fwd
# 124    rwd
# 125    rwd
# 126    rwd
# 127    rwd
# 128    rwd
# 129    rwd
# 130    fwd
# 131    fwd
# 132    fwd
# 133    fwd
# 134    fwd
# 135    fwd
# 136    fwd
# 137    fwd
# 138    fwd
# 139    fwd
# 140    4wd
# 141    fwd
# 142    fwd
# 143    fwd
# 144    4wd
# 145    4wd
# 146    fwd
# 147    fwd
# 148    4wd
# 149    4wd
# 150    fwd
# 151    fwd
# 152    fwd
# 153    fwd
# 154    4wd
# 155    4wd
# 156    fwd
# 157    fwd
# 158    fwd
# 159    fwd
# 160    fwd
# 161    fwd
# 162    fwd
# 163    rwd
# 164    rwd
# 165    rwd
# 166    rwd
# 167    rwd
# 168    rwd
# 169    rwd
# 170    rwd
# 171    rwd
# 172    rwd
# 173    fwd
# 174    fwd
# 175    fwd
# 176    fwd
# 177    fwd
# 178    rwd
# 179    rwd
# 180    rwd
# 181    rwd
# 182    fwd
# 183    fwd
# 184    fwd
# 185    fwd
# 186    fwd
# 187    fwd
# 188    fwd
# 189    fwd
# 190    fwd
# 191    fwd
# 192    fwd
# 193    fwd
# 194    rwd
# 195    rwd
# 196    rwd
# 197    rwd
# 198    rwd
# 199    rwd
# 200    rwd
# 201    rwd
# 202    rwd
# 203    rwd
# 204    rwd
# Name: drive-wheels, dtype: object>

# %%
df_car = pd.get_dummies(df_car, columns=['drive-wheels'])

# %%
df_car.head()
# Out:
#   aspiration num-of-doors num-of-cylinders  doors  cylinders  drive-wheels_4wd  drive-wheels_fwd  drive-wheels_rwd
# 0        std          two             four    2.0          4             False             False              True
# 1        std          two             four    2.0          4             False             False              True
# 2        std          two              six    2.0          6             False             False              True
# 3        std         four             four    4.0          4             False              True             False
# 4        std         four             five    4.0          5              True             False             False

# %%
df_car['aspiration'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        std
# 1        std
# 2        std
# 3        std
# 4        std
# 5        std
# 6        std
# 7        std
# 8      turbo
# 9      turbo
# 10       std
# 11       std
# 12       std
# 13       std
# 14       std
# 15       std
# 16       std
# 17       std
# 18       std
# 19       std
# 20       std
# 21       std
# 22       std
# 23     turbo
# 24       std
# 25       std
# 26       std
# 27     turbo
# 28       std
# 29     turbo
# 30       std
# 31       std
# 32       std
# 33       std
# 34       std
# 35       std
# 36       std
# 37       std
# 38       std
# 39       std
# 40       std
# 41       std
# 42       std
# 43       std
# 44       std
# 45       std
# 46       std
# 47       std
# 48       std
# 49       std
# 50       std
# 51       std
# 52       std
# 53       std
# 54       std
# 55       std
# 56       std
# 57       std
# 58       std
# 59       std
# 60       std
# 61       std
# 62       std
# 63       std
# 64       std
# 65       std
# 66       std
# 67     turbo
# 68     turbo
# 69     turbo
# 70     turbo
# 71       std
# 72       std
# 73       std
# 74       std
# 75     turbo
# 76       std
# 77       std
# 78       std
# 79     turbo
# 80     turbo
# 81       std
# 82     turbo
# 83     turbo
# 84     turbo
# 85       std
# 86       std
# 87     turbo
# 88       std
# 89       std
# 90       std
# 91       std
# 92       std
# 93       std
# 94       std
# 95       std
# 96       std
# 97       std
# 98       std
# 99       std
# 100      std
# 101      std
# 102      std
# 103      std
# 104      std
# 105    turbo
# 106      std
# 107      std
# 108    turbo
# 109      std
# 110    turbo
# 111      std
# 112    turbo
# 113      std
# 114    turbo
# 115      std
# 116    turbo
# 117    turbo
# 118      std
# 119    turbo
# 120      std
# 121      std
# 122      std
# 123      std
# 124    turbo
# 125      std
# 126      std
# 127      std
# 128      std
# 129      std
# 130      std
# 131      std
# 132      std
# 133      std
# 134      std
# 135      std
# 136    turbo
# 137    turbo
# 138      std
# 139      std
# 140      std
# 141      std
# 142      std
# 143      std
# 144      std
# 145    turbo
# 146      std
# 147      std
# 148      std
# 149    turbo
# 150      std
# 151      std
# 152      std
# 153      std
# 154      std
# 155      std
# 156      std
# 157      std
# 158      std
# 159      std
# 160      std
# 161      std
# 162      std
# 163      std
# 164      std
# 165      std
# 166      std
# 167      std
# 168      std
# 169      std
# 170      std
# 171      std
# 172      std
# 173      std
# 174    turbo
# 175      std
# 176      std
# 177      std
# 178      std
# 179      std
# 180      std
# 181      std
# 182      std
# 183      std
# 184      std
# 185      std
# 186      std
# 187    turbo
# 188      std
# 189      std
# 190      std
# 191      std
# 192    turbo
# 193      std
# 194      std
# 195      std
# 196      std
# 197      std
# 198    turbo
# 199    turbo
# 200      std
# 201    turbo
# 202      std
# 203    turbo
# 204    turbo
# Name: aspiration, dtype: object>

# %%
df_car = pd.get_dummies(df_car, columns=['aspiration'], drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df_car = pd.get_dummies(df_car, columns=['aspiration'], drop_first=True)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/reshape/encoding.py:169, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167     raise TypeError("Input must be a list-like for parameter `columns`")
#     168 else:
# --> 169     data_to_encode = data[columns]
#     171 # validate prefixes and separator to avoid silently dropping cols
#     172 def check_len(item, name: str):
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/indexes/base.py:6199, in Index._get_indexer_strict(self, key, axis_name)
#    6196 else:
#    6197     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6199 self._raise_if_missing(keyarr, indexer, axis_name)
#    6201 keyarr = self.take(indexer)
#    6202 if isinstance(key, Index):
#    6203     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/indexes/base.py:6248, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6246 if nmissing:
#    6247     if nmissing == len(indexer):
# -> 6248         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6251     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['aspiration'], dtype='object')] are in the [columns]"

# %%
df_car.head()
# Out:
#   num-of-doors num-of-cylinders  doors  cylinders  drive-wheels_4wd  drive-wheels_fwd  drive-wheels_rwd  aspiration_std  aspiration_turbo
# 0          two             four    2.0          4             False             False              True            True             False
# 1          two             four    2.0          4             False             False              True            True             False
# 2          two              six    2.0          6             False             False              True            True             False
# 3         four             four    4.0          4             False              True             False            True             False
# 4         four             five    4.0          5              True             False             False            True             False
